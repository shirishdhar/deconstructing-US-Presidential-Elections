# %% [markdown]
# ## Part 1

# %% [markdown]
# ### Import Statements

# %%
import numpy as np
import pandas as pd
import csv
import nltk
import re
import os
import gensim
from gensim.models import Word2Vec
from nltk.data import find
import codecs
from sklearn import feature_extraction
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans

# %%
stopwords = nltk.corpus.stopwords.words('english')

# %% [markdown]
# ### Stemmer for stemming words

# %%
from nltk.stem.snowball import SnowballStemmer
stemmer = SnowballStemmer("english")

# %% [markdown]
# ### Data Consolidation

# %%
data = pd.read_csv('Improved Hillary Tweets.csv')
data1 = pd.read_csv('Improved Trump Tweets.csv')
data.append(data1)
# Out:
#        Unnamed: 0                                       clean_tweets  \
# 0               0  No privatization of SS I've paid in I want min...
# 1               1  @timkaine is right Trump would increase debt m...
# 2               2  Hillary Clinton's uninformed know that Hillary...
# 3               3  Hillary Clinton ’ s economic plan would send o...
# 4               4  Do you want a You're Hired president in Hillar...
# 5               5  @HillaryClinton s proud of Clinton Foundation ...
# 6               6  CLINTONS STOLE 94 OF THE DONATIONS TO THAT COU...
# 7               7  Pence claimed Clinton's plans would raise the ...
# 8               8  If past voting records are fair game how about...
# 9               9  there are 359,000 more black voters in battleg...
# 10             10  Kaine says his family trusts Clinton as comman...
# 11             11  I've got a question Tim Should Hillary Clinton...
# 12             12  Hillary Clinton's lawlessness and criminality ...
# 13             13  I ’ m beginning to believe Tim Kaine ’ s debat...
# 14             14  Trump in Arizona with a new twist to his tax r...
# 15             15  Pence Referring to my voting record is just an...
# 16             16  I ’ m beginning to believe Tim Kaine ’ s debat...
# 17             17  Tim Kaine talking over Pence just makes him lo...
# 18             18  Trump and Pence framing the Clinton campaign f...
# 19             19  Question How many Private Sector Jobs has Hill...
# 20             20  I'm so shocked that Trump fans think Kaine is ...
# 21             21  Tim Kaine talking over Pence just makes him lo...
# 22             22  In his first 15 mins Pence has hit Obamacare c...
# 23             23  I wish it were Marco Rubio Jeb Bush Paul Ryan ...
# 24             24  The American people are tired of the spin by C...
# 25             25  mark Tim Kaines words I think Clinton will pri...
# 26             26  Pence is right Clinton Obama tried to negotiat...
# 27             27       Wagers Campaign Cash on Clinton Senate Races
# 28             28  WATCH MSNBC reporter ask millennial women if t...
# 29             29  Family caregivers would get more Social Securi...
# ...           ...                                                ...
# 19970       19970  Nation's Immigration And Customs Enforcement O...
# 19971       19971  u should be mad at Clearly you support her And...
# 19972       19972  GOP congressman I'd back Pence for president o...
# 19973       19973  Tim Kaine Was Right As Fact Checkers Rule Trum...
# 19974       19974  Trump refused to protect our financial system ...
# 19975       19975  New survey of 42 economic experts from the lef...
# 19976       19976  Exactly Trump is NOT brilliant His taxes accou...
# 19977       19977  Here's a weird fucking story about Donald Trum...
# 19978       19978  also manages to get a dig in on Trump in a pos...
# 19979       19979  Nevada TV What if China cut off visas to let p...
# 19980       19980  So Donald Trump lost more than 50mm of daddy's...
# 19981       19981                                 Such a great honor
# 19982       19982  The Trump Foundation scandal is about to go na...
# 19983       19983  Add your name to stand against Donald Trump's ...
# 19984       19984  Clint Eastwood AMERICA IF YOU DON'T GET TRUMP ...
# 19985       19985  Evangelicals support Trump because they believ...
# 19986       19986  Welcome to Weekend Twitter If you don't alread...
# 19987       19987  At least has worked ALL his life.AND he used L...
# 19988       19988  RNC Chair Reince Priebus called Donald Trump a...
# 19989       19989  Hannity accuses Megyn Kelly of being a HILLARY...
# 19990       19990  Trump Only a terrified poverty-stricken ignora...
# 19991       19991  Anti-immigrant anti-Mexican anti-Muslim and an...
# 19992       19992  BREAKING NEWS LEBRON JAMES ENDORSED HILLARY CL...
# 19993       19993  I think I know more about foreign policy than ...
# 19994       19994  Hey Lauren I'm a younger person just of age to...
# 19995       19995  @PrisonPlanet When she says love trumps hate a...
# 19996       19996  Speaking of insult-driven campaigns we've upda...
# 19997       19997  The Trump Foundation scandal is about to go na...
# 19998       19998  Pence gives Trump a reset after Kaine's relent...
# 19999       19999  Trump A insisted he was pronouncing Nevada the...
#
#        favorite  followers  friends                                 hash_tags  \
# 0             0        368     1629                                        []
# 1             0       7033     3906                  ['#debates', '#debates']
# 2             0        505      529                     ['#BasementDwellers']
# 3             0         43      196                       ['#BigLeagueTruth']
# 4             0         25      263                                        []
# 5             0        723     1887                                ['#Trump']
# 6             0       3181     2961                                        []
# 7             0        414      793                                        []
# 8             0         98      104                             ['#VPDebate']
# 9             0        213       34                                        []
# 10            0        276      273                                        []
# 11            0         89      558                             ['#VPDebate']
# 12            0      51720    15318                             ['#VPDebate']
# 13            0        509      909                                        []
# 14            0        111      169                                        []
# 15            0        165      310  ['#VPDebate', '#TimKaine', '#ImWithHer']
# 16            0        747     1682                                        []
# 17            0        156      465                                        []
# 18            0        347      726                             ['#VPDebate']
# 19            0       1930     2059                      ['#VPDebate', '#De']
# 20            0        239      573                                        []
# 21            0        380      361                                        []
# 22            0        207      306                                        []
# 23            0       1351      144                                        []
# 24            0      12580      419                                        []
# 25            0         55      237                             ['#VPDebate']
# 26            0        253      406                                        []
# 27            0       2361     4995                        ['#PrivateEquity']
# 28            0         33       67                    ['#TuesdayMotivation']
# 29            1     330811     1387                             ['#VPdebate']
# ...         ...        ...      ...                                       ...
# 19970         0       1326     1676                                        []
# 19971         0       3117     3807                                        []
# 19972         0       1048      962                                        []
# 19973         0         77      191                                        []
# 19974         0       3886     4010                                        []
# 19975         0         93      108                                        []
# 19976         0        128      514                                        []
# 19977         0        455      392                                        []
# 19978         0        942     3402                                        []
# 19979         0        696      762                                        []
# 19980         0         50       44                                        []
# 19981         0        308       59                                        []
# 19982         0       1135     1112                                        []
# 19983         0       1272     2167                                        []
# 19984         0        820      757                                        []
# 19985         0        154      748                                  ['#mor']
# 19986         0       2497     2319                                        []
# 19987         0        928     1096                 ['#Trump', '#TrumpTrain']
# 19988         0        151      454                                        []
# 19989         0        942     1893                                        []
# 19990         0          1       32                                        []
# 19991         0       1026      692                                        []
# 19992         0        213      262       ['#LebronJames', '#HillaryClinton']
# 19993         0        711      589                                        []
# 19994         0        438      560                                        []
# 19995         0       3755     4988                                        []
# 19996         0         90      281                                        []
# 19997         0         83      268                                        []
# 19998         0       1836       11                                        []
# 19999         0        700     1662                                        []
#
#                 ids       inreplyto  listed                       location  \
# 0               NaN             NaN       5                  Davenport, IA
# 1               NaN             NaN     343                 Washington, DC
# 2               NaN             NaN     115                 Barrington, RI
# 3               NaN             NaN       0                            NaN
# 4               NaN             NaN       0            Utah, United States
# 5               NaN             NaN      63                     Tustin, CA
# 6               NaN             NaN     142                            NaN
# 7               NaN             NaN       5                       Michigan
# 8               NaN             NaN       2                          Texas
# 9               NaN             NaN      51                            NaN
# 10              NaN             NaN      27                            NaN
# 11              NaN             NaN       3                  North America
# 12              NaN             NaN     629                         Texas
# 13              NaN             NaN      18   Hanover, NH and Brooklyn, NY
# 14              NaN             NaN       4                  Rochester, MN
# 15              NaN             NaN      11                    Los Angeles
# 16              NaN             NaN     255                            NaN
# 17              NaN             NaN       4                             MA
# 18              NaN             NaN       1  Columbia, MO & Germantown, TN
# 19              NaN             NaN      70               Atlanta, Georgia
# 20              NaN             NaN       9                            NaN
# 21              NaN             NaN      56                            NaN
# 22              NaN             NaN       9                 Ridgefield, CT
# 23              NaN             NaN      46                        Houston
# 24              NaN             NaN     450            Oxford, Mississippi
# 25              NaN             NaN      16                    Burbank, CA
# 26              NaN             NaN       1                            NaN
# 27              NaN             NaN     241                  United States
# 28              NaN             NaN       3                            NaN
# 29              NaN             NaN    4140                            USA
# ...             ...             ...     ...                            ...
# 19970  9.639654e+08             NaN      34                            NaN
# 19971  3.855376e+08             NaN      96                  New York, USA
# 19972  6.281572e+08             NaN      42                            NaN
# 19973  2.356901e+08             NaN       3            Clearwater, Florida
# 19974  9.144830e+08             NaN     402                            NaN
# 19975  5.518303e+08             NaN       3                            NaN
# 19976  3.207618e+08             NaN       2                        Indiana
# 19977  3.102572e+07             NaN      16                   Columbus, OH
# 19978  7.587095e+17             NaN      95                            NaN
# 19979  1.319967e+08             NaN      18  Toronto & Cape Breton, Canada
# 19980  1.510609e+09             NaN       4                     FL Eustis
# 19981  4.654868e+07             NaN       9                       Michigan
# 19982  2.850301e+08             NaN      30                        Chicago
# 19983  5.603240e+08             NaN      55                   Virginia USA
# 19984  1.806716e+07             NaN     116    North Myrtle Beach, SC, USA
# 19985  2.193718e+09             NaN      25                  Nebraska, USA
# 19986  3.034339e+08             NaN     117   Wherever I Am, United States
# 19987  5.928336e+08    whitebg19611      71                            NaN
# 19988  3.952095e+09             NaN      25                 Washington, DC
# 19989  3.032909e+09             NaN       2                            USA
# 19990  3.149069e+09    BillMoyersHQ       0                 Pittsburgh, PA
# 19991  1.622644e+07             NaN      97        somewhere in the desert
# 19992  3.430173e+09             NaN      40                            NaN
# 19993  4.495687e+09             NaN      67                            NaN
# 19994  2.173149e+09  LouisePentland       0       The Grand Budapest Hotel
# 19995  8.423744e+08    PrisonPlanet      48                       Michigan
# 19996  3.193795e+09             NaN       4                            NaN
# 19997  4.311540e+08             NaN       8                            NaN
# 19998  3.317319e+09             NaN     338                            NaN
# 19999  5.132657e+08             NaN      63                            NaN
#
#        retweet      screen_name state_abbs  \
# 0            0           curish         IA
# 1            2      BudgetHawks         DC
# 2          260       Debbierg51         RI
# 3          427     sandrapelton        NaN
# 4           13          seb_mar         UT
# 5            4        MattM3502         CA
# 6            1      KayWalker10        NaN
# 7            5           Cycle4         MI
# 8            0       RobbieNava         TX
# 9          282      kevtalmadge        NaN
# 10          34        Sharoni03        NaN
# 11          41   powertrip51500        NaN
# 12           0        HeidiL_RN         TX
# 13          60          JHeath_         NY
# 14         544      stacydotcom         MN
# 15           0         jkornack         CA
# 16          60        Diszident        NaN
# 17           9    lmarie_taylor         MA
# 18           0         jrollwde         TN
# 19        1098       nautilus55         GA
# 20           0          evshear        NaN
# 21           9  Civil_war_elect        NaN
# 22          32    georgeregnery         CT
# 23           0      AdamSpolane         TX
# 24           0   angelamcglowan         MS
# 25           0    JoinCobra2016         CA
# 26        1405       oTRUEBLUEo        NaN
# 27           0        MoHossain        NaN
# 28         330          Nevas74        NaN
# 29           0            MONEY        NaN
# ...        ...              ...        ...
# 19970     5440     skstopongi44        NaN
# 19971     2621     Bloggasaurus         NY
# 19972        2      bestemmalab        NaN
# 19973        5      Fllover2011         FL
# 19974      887  BethCol77455974        NaN
# 19975       37   michael_lowder        NaN
# 19976        0         Myshiloh         IN
# 19977        5       dougoldham         OH
# 19978        1    LochnerWalter        NaN
# 19979      355       ZackFraser        NaN
# 19980     5959         Dking002        NaN
# 19981     5358          debdasp         MI
# 19982      309         nancyozz         IL
# 19983       43  KathleenAFranck        NaN
# 19984       34         willie_c         SC
# 19985        1    Racismliveson         NE
# 19986      235     DianaHollins        NaN
# 19987        0       SoyerJanis        NaN
# 19988      485  informationplz_         DC
# 19989        4       ZayraOfUSA        NaN
# 19990        0  PittsburghFrank         PA
# 19991       13      sophievodka        NaN
# 19992        0    ImChrisDaDon1        NaN
# 19993       12     mezzSINGchur        NaN
# 19994        0    Kate_Chaparro        NaN
# 19995        0       MIRightEye         MI
# 19996     1775  soto_michsoto90        NaN
# 19997      309     CandaceMejia        NaN
# 19998       66        ktd101551        NaN
# 19999       43  composthappened        NaN
#
#                                                     text
# 0      No privatization of SS; I've paid in, I want m...
# 1      .@timkaine is right. Trump would increase debt...
# 2      RT @Ian56789: Hillary Clinton's "uninformed" #...
# 3      RT @mike_pence: Hillary Clinton’s economic pla...
# 4      RT @Fusion: "Do you want a You're Hired presid...
# 5      RT @XavierBecerra: .@HillaryClinton's proud of...
# 6      RT @LAYNALANGUAGE: @KayWalker10 @cfoundationsr...
# 7      RT @KevinMKruse: Pence claimed Clinton's plans...
# 8      If past voting records are fair game, how abou...
# 9      RT @JoyAnnReid: "...there are 359,000 more bla...
# 10     RT @hardball: Kaine says his family trusts Cli...
# 11     RT @USAforTrump2016: I've got a question Tim.....
# 12     Hillary Clinton's lawlessness and criminality ...
# 13     RT @EWErickson: I’m beginning to believe Tim K...
# 14     RT @SopanDeb: Trump in Arizona with a...new tw...
# 15     Pence: Referring to my voting record is just a...
# 16     RT @EWErickson: I’m beginning to believe Tim K...
# 17     RT @TrumpRevoluti0n: Tim Kaine talking over Pe...
# 18     Trump and Pence framing the Clinton campaign f...
# 19     RT @immigrant4trump: Question: How many Privat...
# 20     I'm so shocked that Trump fans think Kaine is ...
# 21     RT @TrumpRevoluti0n: Tim Kaine talking over Pe...
# 22     RT @sarahcwestwood: In his first 15 mins Pence...
# 23     I wish it were Marco Rubio, Jeb Bush, Paul Rya...
# 24     The American people are tired of the spin by C...
# 25     #VPDebate mark Tim Kaines words, I think Clint...
# 26     RT @joshrogin: Pence is right. Clinton &amp; O...
# 27     #PrivateEquity Wagers Campaign Cash on Clinton...
# 28     RT @asamjulian: WATCH: MSNBC reporter ask mill...
# 29     Family caregivers would get more Social Securi...
# ...                                                  ...
# 19970  RT @realDonaldTrump: Nation's Immigration And ...
# 19971  RT @seanhannity: @megynkelly u should be mad a...
# 19972  RT @thehill: GOP congressman: I'd back Pence f...
# 19973  RT @ArthurA_P: Tim Kaine Was Right As Fact Che...
# 19974  RT @mcuban: Trump refused to protect our finan...
# 19975  RT @scottlincicome: New survey of 42 economic ...
# 19976  Exactly. Trump is NOT brilliant. His taxes acc...
# 19977  RT @Deadspin: Here's a weird fucking story abo...
# 19978  RT @PCalith: @PCalith also manages to get a di...
# 19979  RT @ddale8: Nevada TV: What if China cut off v...
# 19980  RT @mcuban: So Donald Trump lost more than $50...
# 19981  RT @realDonaldTrump: Such a great honor! \r\r\...
# 19982  RT @kylegriffin1: The Trump Foundation scandal...
# 19983  RT @HillaryforCO: Add your name to stand again...
# 19984  RT @StopStopHillary: Clint Eastwood: "AMERICA,...
# 19985  RT @redact_group: Evangelicals support Trump b...
# 19986  RT @bornmiserable: Welcome to Weekend Twitter....
# 19987  @whitebg19611 @HillaryClinton At least #Trump ...
# 19988  RT @kylegriffin1: RNC Chair Reince Priebus cal...
# 19989  RT @slone: Hannity accuses Megyn Kelly of bein...
# 19990  @BillMoyersHQ Trump: "Only a terrified, povert...
# 19991  RT @politico: "Anti-immigrant, anti-Mexican, a...
# 19992  BREAKING NEWS! LEBRON JAMES ENDORSED HILLARY C...
# 19993  RT @LPDonovan: "I think I know more about fore...
# 19994  @LouisePentland @LaurenG1993 Hey Lauren!I'm a ...
# 19995  .@PrisonPlanet When she says love trumps hate ...
# 19996  RT @KevinQ: Speaking of insult-driven campaign...
# 19997  RT @kylegriffin1: The Trump Foundation scandal...
# 19998  RT @FoxNews: Pence gives Trump a reset after K...
# 19999  RT @SheWhoVotes: Trump A) insisted he was pron...
#
# [40000 rows x 14 columns]

# %% [markdown]
# ### Removing Invalid States and Creating A Dictionary with key = state name and value = all tweets for the state

# %%
states=set(list(data.state_abbs))
states=list(states)
states=[str(state) for state in states]
states.remove('nan')

# %%
dictdata={}
for state in states:
    statedata=data.loc[data['state_abbs'] == state]
    listoftweets=list(statedata['clean_tweets'])
    dictdata[state] = ' '.join(listoftweets)

# %%
dictdata['AK']
# Out:
# "Bill and Hillary Clinton Foundation Received 81 Million In Donations Through Swiss Bank Under Investigation Hillary Clinton ’ s economic plan would send our economy into a tailspin When Hillary Clinton became Secretary of State Chris Stevens Ty Woods Sean Smith Glen Doherty were still alive … One thing's clear and Hillary have hardworking Americans backs The VP's office is in good hands – Joe Can't wait for Hillary supporters who have a problem with Trump's demeanor attempt to defend Tim Kaine's obnoxious … Its as hard to watch Kaine as it is to watch hillary Its as hard to watch Kaine as it is to watch hillary FLASHBACK Hillary Clinton's Failed Foreign Policy ➡ ️ SYRIA FLASHBACK Hillary Clinton's Failed Foreign Policy ➡ ️ SYRIA FLASHBACK Hillary Clinton's Failed Foreign Policy ➡ ️ SYRIA FLASHBACK Hillary Clinton's Failed Foreign Policy ➡ ️ SYRIA"

# %% [markdown]
# ### Keeping Only Nouns Within Tweets For The Purpose of Clustering

# %%
for key in list(dictdata.keys()):
    noundata=dictdata[key]
    tokens=nltk.word_tokenize(noundata)
    noundata=[word[0] for word in nltk.pos_tag(tokens) if word[1] == 'NN']
    noundata=' '.join(noundata)
    dictdata[key]=noundata

# %%
statename=[]
tweetdata=[]
for key in dictdata.keys():
    statename.append(key)
    tweetdata.append(dictdata[key])

# %% [markdown]
# Note: The code beyond this point is a modified implementation of K-means clustering as made available to general public by Brandon Rose. The original implementation may be found at brandonrose.org/clustering

# %% [markdown]
# ### Tokenization

# %%
def tokenize(text):
    # first tokenize by sentence, then by word to ensure that punctuation is caught as it's own token
    tokens = [word.lower() for sent in nltk.sent_tokenize(text) for word in nltk.word_tokenize(sent)]
    filtered_tokens = []
    # filter out any tokens not containing letters (e.g., numeric tokens, raw punctuation)
    for token in tokens:
        pattern = r'''(?x)  # allow verbose regexps
        (?:[A-Z]\.)+        # abbreviations
        |\w+(?:[-']\w+)*    # words with optional internal hyphens
        |\$?\d+(?:\.\d+)?   # currency
        |\.\.\.             # elipses
        |[.,;"'?()-_`]      # these are separate tokens
        '''
        if re.search(pattern, token):
            filtered_tokens.append(token)
            
    return filtered_tokens

# %% [markdown]
# ### Splitting data into paragraphs, to be used as entities for k-means clustering (after vectorization using TF-IDF).

# %%
totalvocab_tokenized = []
for i in tweetdata:
    allwords_tokenized = tokenize(i)
    totalvocab_tokenized.extend(allwords_tokenized)

# %%
vocab_frame = pd.DataFrame({'words': totalvocab_tokenized}, index = totalvocab_tokenized)

# %% [markdown]
# ### TF-IDF

# %%
tfidf_vectorizer = TfidfVectorizer(min_df=3, stop_words='english',tokenizer=tokenize, ngram_range=(1,3))
tfidf_matrix = tfidf_vectorizer.fit_transform(tweetdata)

# %%
terms = tfidf_vectorizer.get_feature_names()

# %% [markdown]
# ### We perform K-Means clustering with number of clusters as 5.

# %%
cluster = KMeans(n_clusters=5)
cluster.fit(tfidf_matrix)
clusters = cluster.labels_.tolist()

# %%
paragraphs = { 'state': statename, 'tweet': tweetdata, 'cluster': clusters}

frame = pd.DataFrame(paragraphs, index = [clusters] , columns = ['state', 'cluster'])

# %%
frame['cluster'].value_counts()
# Out:
# 2    25
# 1     8
# 4     7
# 3     6
# 0     6
# Name: cluster, dtype: int64

# %% [markdown]
# #### Output for number of clusters (k) = 5

# %%
from __future__ import print_function

print("Top terms per cluster:")
print()
order_centroids = cluster.cluster_centers_.argsort()[:, ::-1] 
clusterstate={}
for i in range(5):
    print("Cluster %d words:" % i, end='')
    
    for ind in order_centroids[i, :50]:
        print(' %s' % vocab_frame.ix[terms[ind].split(' ')].values.tolist()[0][0], end=',')
    print() #add whitespace
    print() #add whitespace
    
    print("Cluster %d states:" % i, end='')
    clusterstate[i] = frame.ix[i]['state'].values.tolist()
    for title in frame.ix[i]['state'].values.tolist():
        print(' %s' % title, end='')
    print() #add whitespace
    print() #add whitespace
    
print()
print()
# Out:
# Top terms per cluster:
#
# Cluster 0 words: thing, thing, world, thing, world, world, video, candidate, video, camp, pander, poll, drone, mike_pence, lack, thing, camp, thing, camp, lack, mouth, yeah, likability, puppet, hurricane, strike, smugness, puppet, election, email, email, server, ad, campaign, agreement, time, lead, trump, economy, mess, server, email, plan, economy, plan, tailspin, plan, dealer, policy, extension,
#
# Cluster 0 states: DE WA WY CO NV NM
#
# Cluster 1 words: interview, hacker, make, hacker, hacker, make, difference, memo, memo, make, difference, difference, world, intersection, poll, president, plan, campaign, thing, head, spokesman, campaign, poll, economy, poll, h, thing, guy, indictment, night, economy, tailspin, plan, party, debate, moderator, moderator, plan, leader, interrupting, interrupting, night, college, interrupting, loving, moderator, commish, commish, commish, mercy,
#
# Cluster 1 states: IL OH AZ MS DC NE NH SC
#
# Cluster 2 words: campaign, indictment, plan, president, s, debate, indictment, judgement, htt, troop, extension, troop, troop, extension, life, economy, admin, job, rally, strategy, plan, democracy, crazy, thing, time, report, fact, liar, poll, disaster, plan, economy, tailspin, president, problem, immigration, agreement, relief, story, judgement, demeanor, joke, east, problem, problem, demeanor, indictment, judgement, attempt, policy,
#
# Cluster 2 states: MO ND CA NJ IN CT RI OR HI FL AL KS ID NY NC TX PR IA AK ME KY LA VT PA UT
#
# Cluster 3 words: pay, home, home, ad, measure, home, cartoon, evidence, ad, week, work, immigration, immigration, deportation, reform, immigration, reform, rally, adviser, adviser, adviser, create, frankly, frankly, image, cut, coverage, justice, intersection, create, frankly, policy, pass, s, measure, measure, ad, child, s, right, tax, rally, rally, tomorrow, tomorrow, s, way, hurricane, dont, policy,
#
# Cluster 3 states: SD MD AR MN MT MA
#
# Cluster 4 words: injustice, dealer, mike_pence, dealer, mike_pence, truth, truth, mike_pence, truth, campaign, tax, world, injustice, injustice, dealer, today, disaster, statement, wall, access, plan, admin, leader, debt, world, thing, war, thing, world, event, ht, reason, home, thing, debate, h, tax, line, support, decision, tax, trustworthiness, reason, law, ass, head, attention, n, staff, time,
#
# Cluster 4 states: TN GA WI MI OK VA WV

# %%
clusterstate
# Out:
# {0: ['DE', 'WA', 'WY', 'CO', 'NV', 'NM'],
#  1: ['IL', 'OH', 'AZ', 'MS', 'DC', 'NE', 'NH', 'SC'],
#  2: ['MO',
#   'ND',
#   'CA',
#   'NJ',
#   'IN',
#   'CT',
#   'RI',
#   'OR',
#   'HI',
#   'FL',
#   'AL',
#   'KS',
#   'ID',
#   'NY',
#   'NC',
#   'TX',
#   'PR',
#   'IA',
#   'AK',
#   'ME',
#   'KY',
#   'LA',
#   'VT',
#   'PA',
#   'UT'],
#  3: ['SD', 'MD', 'AR', 'MN', 'MT', 'MA'],
#  4: ['TN', 'GA', 'WI', 'MI', 'OK', 'VA', 'WV']}

# %% [markdown]
# ### Representing Data in Tabular Format for Visualization using Tableau

# %%
clusterdata = {}
for keys in clusterstate:
    for items in clusterstate[keys]:
        clusterdata[items] = keys

# %%
clusterresults = pd.DataFrame([key,clusterdata[key]] for key in clusterdata)

# %%
clusterresults
# Out:
#      0  1
# 0   SC  1
# 1   TN  4
# 2   GA  4
# 3   MO  2
# 4   SD  3
# 5   ND  2
# 6   CA  2
# 7   NJ  2
# 8   CT  2
# 9   IN  2
# 10  IL  1
# 11  MD  3
# 12  RI  2
# 13  HI  2
# 14  FL  2
# 15  WA  0
# 16  AL  2
# 17  KS  2
# 18  AR  3
# 19  OH  1
# 20  AZ  1
# 21  MS  1
# 22  ID  2
# 23  DC  1
# 24  ME  2
# 25  TX  2
# 26  NY  2
# 27  NC  2
# 28  WI  4
# 29  WY  0
# 30  MI  4
# 31  NE  1
# 32  PR  2
# 33  IA  2
# 34  CO  0
# 35  OK  4
# 36  AK  2
# 37  OR  2
# 38  MN  3
# 39  NH  1
# 40  KY  2
# 41  DE  0
# 42  NV  0
# 43  MT  3
# 44  VA  4
# 45  LA  2
# 46  VT  2
# 47  WV  4
# 48  PA  2
# 49  UT  2
# 50  MA  3
# 51  NM  0

# %%
clusterresults.to_csv('clusters.csv')
